# %% [markdown]
# <h1>Comparar los salarios promedio entre científicos de datos y otros profesionales en áreas de datos para obtener aquel que tiene mejor salario.<h1>

# %%
import pandas as pd

# %%
df_salaries = pd.read_csv("../ds_salaries_US.csv")
df_salaries
# Out:
#       Unnamed: 0  work_year experience_level employment_type  \
# 0              1       2023               MI              CT
# 1              2       2023               MI              CT
# 2              5       2023               SE              FT
# 3              6       2023               SE              FT
# 4              9       2023               SE              FT
# ...          ...        ...              ...             ...
# 3035        3749       2021               SE              FT
# 3036        3750       2020               SE              FT
# 3037        3751       2021               MI              FT
# 3038        3752       2020               EN              FT
# 3039        3753       2020               EN              CT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 0                  ML Engineer   30000             USD          30000
# 1                  ML Engineer   25500             USD          25500
# ...

# %%
# Datos Unicos
df_salaries["job_category"].unique()
# Out:
# array(['Data Engineer', 'Data Scientist', 'Data Analyst', 'Other'],
#       dtype=object)

# %% [markdown]
# # Data Scientist

# %%
columnas = ["job_category","salary_in_usd"]

# %%
salaries_DS = df_salaries[ df_salaries['job_category'] == 'Data Scientist'] [columnas]
salaries_DS
# Out:
#         job_category  salary_in_usd
# 2     Data Scientist         222200
# 3     Data Scientist         136000
# 4     Data Scientist         147100
# 5     Data Scientist          90700
# 8     Data Scientist         213660
# ...              ...            ...
# 3032  Data Scientist         138350
# 3034  Data Scientist         423000
# 3036  Data Scientist         412000
# 3037  Data Scientist         151000
# 3038  Data Scientist         105000
#
# [968 rows x 2 columns]

# %%
n_DS = len(salaries_DS)
print(f"Tamaño de la muestra es {n_DS}")
# Out:
# Tamaño de la muestra es 968

# %% [markdown]
# # Data Engineer

# %%
salaries_DE = df_salaries[ df_salaries['job_category'] == 'Data Engineer'][columnas]
salaries_DE
# Out:
#        job_category  salary_in_usd
# 0     Data Engineer          30000
# 1     Data Engineer          25500
# 16    Data Engineer         225000
# 17    Data Engineer         156400
# 18    Data Engineer         200000
# ...             ...            ...
# 3017  Data Engineer         165000
# 3018  Data Engineer         185000
# 3019  Data Engineer         110000
# 3022  Data Engineer          60000
# 3033  Data Engineer         130800
#
# [1453 rows x 2 columns]

# %%
n_DE = len(salaries_DE)
print(f"Tamaño de la muestra es {n_DE}")
# Out:
# Tamaño de la muestra es 1453

# %% [markdown]
# # Data Analyst

# %%
salaries_DA = df_salaries[ df_salaries['job_category'] == 'Data Analyst'][columnas]
salaries_DA
# Out:
#       job_category  salary_in_usd
# 6     Data Analyst         130000
# 7     Data Analyst         100000
# 14    Data Analyst         150000
# 15    Data Analyst         110000
# 26    Data Analyst         105380
# ...            ...            ...
# 3007  Data Analyst          85000
# 3010  Data Analyst          98000
# 3027  Data Analyst          75000
# 3028  Data Analyst          62000
# 3039  Data Analyst         100000
#
# [563 rows x 2 columns]

# %%
n_DA = len(salaries_DA)
print(f"Tamaño de la muestra es {n_DA}")
# Out:
# Tamaño de la muestra es 563

# %% [markdown]
# # PRUEBAS DE HIPÓTESIS

# %% [markdown]
# Data Scientist y Data Engineer
#
#
#
# Ho : media_DS => media_DE
#
# Ha : media_DS < media_DE

# %%
test_result <- t.test(salaries_DS, salaries_DE, alternative = "less", conf.level = 0.95)
# Out:
#   Cell In[73], line 1
#     test_result <- t.test(salaries_DS, salaries_DE, alternative = "less", conf.level = 0.95)
#                                                                           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
